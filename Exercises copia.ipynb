# %%
import pandas as pd 
import yfinance as yf
import numpy as np
import scipy.stats as scs
from scipy.stats import randint,norm
import matplotlib.pyplot as plt
import scienceplots
#plt.style.use('science')
# %matplotlib inline

import datetime as dt
from pandas.plotting import scatter_matrix

import seaborn as sns

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import normal_ad, het_arch
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.stattools import jarque_bera
from scipy.stats import shapiro

# %% [markdown]
# # Phase 1: Exploratory Data Analysis (EDA) of the Assets
#
# ## Steps performed
#
# ### 1. Data Download
# - Collection of historical data for the selected assets.
#
# ### 2. Dataset Description
# - Preliminary analysis of the downloaded dataset (size, variables, data frequency).
#
# ### 3. Statistical Plots
# - Visualization of the main descriptive statistics through graphs.
#
# ### 4. Autocorrelation Analysis
# - Computation and visualization of the autocorrelation function (ACF).
# - Analysis performed on both returns and squared returns.
#
# ### 5. Statistical Tests
# - **Augmented Dickey-Fuller (ADF) test**
# - **Jarque-Bera test**
# - **Shapiro-Wilk test**
# - **Engle’s ARCH test**
# - **Anderson-Darling test**
#
# ### 6. Correlation Analysis
# - Computation of static correlation between assets.
# - Rolling dynamic correlation to assess time-varying relationships.
#
# ### 7. Cross-Correlation
# - Study of cross-correlations among the different asset returns.

# %%
def calculate_metrics(dff):
    log_ret = np.log(dff) - np.log(dff).shift(1)
    avg_ret = log_ret.mean() * 252
    log_std=log_ret.rolling(30).std()
    avg_std=log_ret.std()*np.sqrt(252)
    z=norm.ppf(0.05)
    #VaR parametrico 
    var95_p=-(avg_ret+z*avg_std)
    #VaR empirico 
    var95_e = -log_ret.quantile(0.05)
    es95_p=log_ret[log_ret<log_ret.quantile(0.05)].mean()*252
    DD= dff/dff.cummax()-1
    max_DD=DD.min()
    downside_std=log_ret[log_ret<0].std()*np.sqrt(252) #standard deviation dei soli rendimenti negativi

    return log_ret,avg_ret,log_std, avg_std, var95_p,var95_e, es95_p, max_DD, downside_std

def get_data(tickers,start,end):
    df=yf.download(tickers,start=start,end=end,interval='1d',group_by='ticker')
    df = df.xs('Close', axis=1, level=1) #serve ad accedere al livello corretto del dataset da quando yfinance è stato aggiornato
    return df


def describestat(array):
    p = scs.describe(array)
    results = {
        "size":     p[0],
        "min":      p[1][0],
        "max":      p[1][1],
        "mean":     p[2],
        "std":      p[3],
        "skewness": p[4],
        "kurtosis": p[5],
    }
    # opzionale: stampa
    print("statistic values")
    for k,v in results.items():
        print(f"{k:>12} {v:15.5f}")
    return results

# %%
tickers=['PEP','GOOGL','AMZN','NVDA'] #choose the tickers you prefer
end=dt.datetime.now()
start=end-dt.timedelta(days=4000)
df=get_data(tickers,start,end)
df
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  4 of 4 completed
# Ticker           GOOGL        AMZN        NVDA         PEP
# Date
# 2014-09-18   29.685465   16.250000    0.464541   67.988373
# 2014-09-19   30.089542   16.566000    0.455939   68.294159
# 2014-09-22   29.685465   16.225000    0.451399   68.141281
# 2014-09-23   29.382780   16.181499    0.449487   67.667961
# 2014-09-24   29.742624   16.410500    0.452115   68.083023
# ...                ...         ...         ...         ...
# 2025-08-25  208.490005  227.940002  179.809998  148.199997
# 2025-08-26  207.139999  228.710007  181.770004  147.000000
# 2025-08-27  207.479996  229.119995  181.600006  147.639999
# 2025-08-28  211.639999  231.600006  180.169998  146.979996
# 2025-08-29  212.910004  229.000000  174.179993  148.649994
#
# [2754 rows x 4 columns]

# %%
df.isna().sum() 
# check the na values
# Out:
# Ticker
# GOOGL    0
# AMZN     0
# NVDA     0
# PEP      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2754 entries, 2014-09-18 to 2025-08-29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GOOGL   2754 non-null   float64
#  1   AMZN    2754 non-null   float64
#  2   NVDA    2754 non-null   float64
#  3   PEP     2754 non-null   float64
# dtypes: float64(4)
# memory usage: 107.6 KB

# %%
df.describe()
# Out:
# Ticker        GOOGL         AMZN         NVDA          PEP
# count   2754.000000  2754.000000  2754.000000  2754.000000
# mean      86.504538   105.603321    27.307301   117.359994
# std       48.511710    60.087288    42.322881    34.276997
# min       24.704838    14.347500     0.401217    66.109703
# 25%       46.822068    48.067501     3.415123    87.005182
# 50%       67.428112    95.854248     6.770607   114.978230
# 75%      128.325394   159.218994    25.436983   151.941540
# max      212.910004   242.059998   183.160004   182.348969

# %%
log_ret,avg_ret,log_std,avg_std,var95,var95_e,es,maxdd,down_std= calculate_metrics(df)
log_ret_clean = log_ret.replace([np.inf, -np.inf], np.nan).dropna()
log_std_clean=log_std.replace([np.inf, -np.inf], np.nan).dropna()

#Plotted Gaussian assumptions only. It should be compared with the empricial ones computed above to 
#show how the parametric normality framework does not work.
fig, axes = plt.subplots(2, 1, figsize=(12,8), sharex=True)
log_ret_clean.plot(ax=axes[0], title="Log Returns")
axes[0].axhline(-var95.loc['AMZN'],label='var_AMZN',color='blue')
axes[0].axhline(-var95.loc['PEP'],label='var_PEP',color="#D70303")
axes[0].axhline(-var95.loc['GOOGL'],label='var_GOOGL',color='orange')
axes[0].axhline(-var95.loc['NVDA'],label='var_NVDA',color='green')
axes[0].legend()

(log_std_clean/log_std_clean.iloc[0]).plot(ax=axes[1], title="Log Std") #indicizzato a 1
plt.tight_layout()
axes[1].legend()

plt.show()

# %%
results = {}

for t in tickers:
    log_data = np.array(log_ret_clean[t].dropna())
    results[t] = describestat(log_data)

df_stats = pd.DataFrame.from_dict(results, orient="index")
# Out:
# statistic values
#         size      2753.00000
#          min        -0.12136
#          max         0.12166
#         mean         0.00028
#          std         0.00014
#     skewness        -0.47981
#     kurtosis        19.38430
# statistic values
#         size      2753.00000
#          min        -0.12368
#          max         0.15065
#         mean         0.00072
#          std         0.00032
#     skewness        -0.00905
#     kurtosis         5.94714
# statistic values
#         size      2753.00000
#          min        -0.15140
#          max         0.13218
#         mean         0.00096
#          std         0.00043
#     skewness         0.12438
#     kurtosis         5.83760
# statistic values
#         size      2753.00000
#          min        -0.20771
#          max         0.26088
#         mean         0.00215
#          std         0.00092
#     skewness         0.13848
#     kurtosis         7.03938

# %%
metrics = ["mean","std","skewness","kurtosis"]

# Barplot comparativi
df_stats[metrics].plot(kind="bar", subplots=True, layout=(2,2),
                       figsize=(12,8), legend=False, sharex=True)
plt.tight_layout(); plt.show()

# %%
plt.figure(figsize=(12,6))
ret_ = log_ret_clean['NVDA'].dropna()
sns.histplot(ret_, bins=50, kde=True, color='green', stat='density', label='Empirical distribution')
plt.title("Density distribution of log returns")
plt.xlabel("Log return")
plt.ylabel("Probability density")

mu, sigma = norm.fit(ret_)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
plt.plot(x, p, 'k', linewidth=2, label='Normal')
plt.axvline(mu, color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(mu+sigma, color='green', linestyle='dashed', linewidth=2)
plt.axvline(mu-sigma, color='green', linestyle='dashed', linewidth=2)
plt.axvline(mu+2*sigma, color='b', linestyle='dashed', linewidth=2)
plt.axvline(mu-2*sigma, color='b', linestyle='dashed', linewidth=2)

plt.text(mu, plt.ylim()[1]*0.9, 'Mean', color='r', ha='center')
plt.text(mu+sigma, plt.ylim()[1]*0.9, '1std', color='g', ha='center')
plt.text(mu-sigma, plt.ylim()[1]*0.9, '1std', color='g', ha='center')
plt.text(mu+2*sigma, plt.ylim()[1]*0.9, '2std', color='b', ha='center')
plt.text(mu-2*sigma, plt.ylim()[1]*0.9, '2std', color='b', ha='center')

title = 'Fit results: mu=%.4f, sigma=%.4f' % (mu, sigma)
plt.title(title)
plt.legend()
plt.show()

# %%
plot_acf(log_ret_clean['AMZN'],lags=50)
plt.show()

# %%
plot_acf(log_ret_clean["AMZN"].dropna()**2, lags=50)
plt.title("ACF dei ritorni al quadrato")
plt.show()

# %%
r = log_ret_clean['AMZN']

ad_stat, ad_p = normal_ad(r)
jb_stat, jb_p, jb_skew, jb_kurt = jarque_bera(r)
sh_stat, sh_p = shapiro(r.sample(min(5000, len(r)), random_state=42))

print(f"Anderson–Darling: stat={ad_stat:.4f}, p={ad_p:.4g}")
print(f"Jarque–Bera : stat={jb_stat:.4f}, p={jb_p:.4g} | skew={jb_skew:.3f}, kurt={jb_kurt:.3f}")
print(f"Shapiro–Wilk    : stat={sh_stat:.4f}, p={sh_p:.4g}")

adf_stat, adf_p, adf_lags, adf_n, adf_crit, *_ = adfuller(r, autolag="AIC")
print(f"\nADF test: stat={adf_stat:.4f}, p={adf_p:.4g}, lags={adf_lags}, n={adf_n}")
print(f"Critical values: {adf_crit}")

arch_stat, arch_p, arch_lags, _ = het_arch(r, nlags=20)
print(f"\nARCH LM (20 lags): stat={arch_stat:.4f}, p={arch_p:.4g}, used_lags={arch_lags}")
# Out:
# Anderson–Darling: stat=inf, p=0
# Jarque–Bera     : stat=4057.1002, p=0 | skew=-0.009, kurt=8.947
# Shapiro–Wilk    : stat=0.9374, p=1.415e-32
#
# ADF test: stat=-18.1438, p=2.487e-30, lags=8, n=2744
# Critical values: {'1%': -3.4327353600205757, '5%': -2.862593880583324, '10%': -2.5673310144635737}
#
# ARCH LM (20 lags): stat=141.9256, p=2.181e-20, used_lags=7.427466100549726

# %%
#let's see the assets correlations
corr= log_ret_clean.corr()
sns.heatmap(corr,annot=True,cmap='jet')
plt.show()

# %%
#rolling correlation
window=30
rolling=[]
for i in range(window,len(log_ret_clean)):
    w=log_ret_clean.iloc[i-window:i].corr()
    rolling.append(w)
date=log_ret_clean.index
rolling_dates=date[window:]

corr_mat = [mat["AMZN"]["PEP"] for mat in rolling]
plt.figure(figsize=(12,6))
plt.axhline(np.mean(corr_mat),color='red',label=f"mean correlation : {np.round(np.mean(corr_mat),2)}")
plt.axhline(0,color='black')
plt.plot(rolling_dates,corr_mat,'-')
plt.legend(fontsize=9)
plt.show()

# %%
from statsmodels.tsa.stattools import ccf
import matplotlib.pyplot as plt

N=len(log_ret_clean)
x = log_ret_clean["PEP"].dropna()
y = log_ret_clean["NVDA"].dropna()

ccf_vals = ccf(x, y)[:40]  # fisrt 40 lags
plt.bar(range(len(ccf_vals)), ccf_vals)
plt.axhline(0, color='k')
plt.axhline(2/np.sqrt(N), color='red')
plt.axhline(-2/np.sqrt(N), color='red')
plt.title("Cross-Correlation Function")
plt.show()

# %% [markdown]
# # Second Phase : Preprocessing

# %%
# log Realized volatility with windows of 5,15,30
h1=5
h2=15
h3=30
log_realized_volatility_5= np.log(log_ret_clean.rolling(h1).std()).dropna()
log_realized_volatility_15= np.log(log_ret_clean.rolling(h2).std()).dropna()
log_realized_volatility_30= np.log(log_ret_clean.rolling(h3).std()).dropna()

# %%
log_realized_volatility_5.plot(title='5days std',figsize=(10,6),alpha=0.8)
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Log-realized volatility')
plt.axhline(np.mean(log_realized_volatility_5),linestyle='--',color='blue',label=f"average rolling std")
plt.legend(fontsize=8)
plt.show()
log_realized_volatility_15.plot(title='15days std',figsize=(10,6),alpha=0.8)
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Log-realized volatility')
plt.axhline(np.mean(log_realized_volatility_15),linestyle='--',color='blue',label=f"average rolling std")
plt.legend(fontsize=8)
plt.show()
log_realized_volatility_30.plot(title='30days std',figsize=(10,6),alpha=0.8)
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Log-realized volatility')
plt.axhline(np.mean(log_realized_volatility_30),linestyle='--',color='blue',label=f"average rolling std")
plt.legend(fontsize=8)
plt.show()

# %%
# ATR 
dfs=[]
tickers=['PEP','GOOGL','AMZN','NVDA']
df=yf.download(tickers,start=start,end=end,interval='1d',group_by='ticker')
for i in tickers:
    dff=df[i]
    dfs.append(dff)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df_pep=dfs[0]
df_googl=dfs[1]
df_AMZN=dfs[2]
df_NVDA=dfs[3]

# %%
def ATR(df,n=14):
    high=df['High']
    low=df['Low']
    close=df['Close']

    tr1 = high - low
    tr2 = (high - close.shift()).abs()
    tr3 = (low - close.shift()).abs()
    tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)

    # ATR iniziale 
    atr = pd.Series(np.nan, index=df.index)
    atr.iloc[n-1] = tr.iloc[:n].mean()

    
    for i in range(n, len(tr)):
        atr.iloc[i] = (atr.iloc[i-1] * (n-1) + tr.iloc[i]) / n

    return atr

# %%
pep_atr=pd.DataFrame(ATR(df_pep).dropna())
googl_atr=pd.DataFrame(ATR(df_googl).dropna())
#googl_atr.reset_index(inplace=True)
amzn_atr=pd.DataFrame(ATR(df_AMZN).dropna())
#amzn_atr.reset_index(inplace=True)
nvda_atr=pd.DataFrame(ATR(df_NVDA).dropna())
#nvda_atr.reset_index(inplace=True)

# %%
pep_atr.columns=['PEP_ATR']
pep_atr.reset_index(inplace=True)
googl_atr.columns=['GOOGL_ATR']
googl_atr.reset_index(inplace=True)
amzn_atr.columns=['AMZN_ATR']
amzn_atr.reset_index(inplace=True)
nvda_atr.columns=['NVDA_ATR']
nvda_atr.reset_index(inplace=True)


# Merge alltoghether
atr_pep_googl=pd.merge(pep_atr,googl_atr,how='inner',on='Date')
atr_nvda_amzn=pd.merge(nvda_atr,amzn_atr,how='inner',on='Date')
df_atr_final=pd.merge(atr_nvda_amzn,atr_pep_googl,how='inner',on='Date')
df_atr_final.set_index('Date')
# Out:
#             NVDA_ATR  AMZN_ATR   PEP_ATR  GOOGL_ATR
# Date
# 2014-10-07  0.009132  0.325821  0.578887   0.434040
# 2014-10-08  0.009469  0.338156  0.598911   0.463567
# 2014-10-09  0.009647  0.343216  0.694483   0.482678
# 2014-10-10  0.010784  0.341522  0.766063   0.519985
# 2014-10-13  0.010918  0.351877  0.795603   0.541243
# ...              ...       ...       ...        ...
# 2025-08-25  4.709296  4.993071  2.586480   4.532006
# 2025-08-26  4.628633  4.849280  2.576018   4.407577
# 2025-08-27  4.540159  4.650045  2.497730   4.325608
# 2025-08-28  4.791576  4.652899  2.448607   4.396637
# 2025-08-29  4.950749  4.581263  2.441564   4.400448
#
# [2741 rows x 4 columns]

# %%
# altre features sono i ritorni in modulo

log_ret_abs=np.abs(log_ret_clean)
log_ret_abs.columns=['AMZN_ret_abs','NVDA_ret_abs','GOOGL_ret_abs','PEP_ret_abs']
log_realized_volatility_15.columns=['AMZN_std15','NVDA_std15','GOOGL_std15','PEP_std15']
log_realized_volatility_5.columns=['AMZN_std5','NVDA_std5','GOOGL_std5','PEP_std5']
log_realized_volatility_30.columns=['AMZN_std30','NVDA_std30','GOOGL_std30','PEP_std30']
df1=pd.merge(log_ret_abs,log_realized_volatility_15,how='inner',on='Date')
df2=pd.merge(df1,log_realized_volatility_5,how='inner',on='Date')
df3=pd.merge(df2,log_realized_volatility_30,how='inner',on='Date')
df4=pd.merge(df3,df_atr_final,how='inner',on='Date')
df4.set_index('Date',inplace=True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2724 entries, 2014-10-30 to 2025-08-29
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AMZN_ret_abs   2724 non-null   float64
#  1   NVDA_ret_abs   2724 non-null   float64
#  2   GOOGL_ret_abs  2724 non-null   float64
#  3   PEP_ret_abs    2724 non-null   float64
#  4   AMZN_std15     2724 non-null   float64
#  5   NVDA_std15     2724 non-null   float64
#  6   GOOGL_std15    2724 non-null   float64
#  7   PEP_std15      2724 non-null   float64
#  8   AMZN_std5      2724 non-null   float64
#  9   NVDA_std5      2724 non-null   float64
#  10  GOOGL_std5     2724 non-null   float64
#  11  PEP_std5       2724 non-null   float64
#  12  AMZN_std30     2724 non-null   float64
#  13  NVDA_std30     2724 non-null   float64
#  14  GOOGL_std30    2724 non-null   float64
#  15  PEP_std30      2724 non-null   float64
#  16  NVDA_ATR       2724 non-null   float64
#  17  AMZN_ATR       2724 non-null   float64
#  18  PEP_ATR        2724 non-null   float64
#  19  GOOGL_ATR      2724 non-null   float64
# dtypes: float64(20)
# memory usage: 446.9 KB

# %% [markdown]
# # Preproceesing, solo un asset per ora

# %%
df = df4.copy()

h = 10  # future windows

# example for AMZN
X_amzn = df[['AMZN_ret_abs','AMZN_std5','AMZN_std15','AMZN_std30','AMZN_ATR']]

def build_vol_targets_multi_horizon(abs_ret: pd.Series, H: int = 10):
    
    sq = abs_ret.pow(2)
    out = {}
    for k in range(1, H+1):
        rv_k = sq.shift(-1).rolling(window=k, min_periods=k).sum().pow(0.5)
        out[f'h{k}'] = np.log(rv_k.replace(0, np.nan))
    return pd.DataFrame(out)

H = 10
Y_amzn = build_vol_targets_multi_horizon(df['AMZN_ret_abs'], H=H)
data = X_amzn.join(Y_amzn, how='inner').replace([np.inf, -np.inf], np.nan).dropna()
X = data[X_amzn.columns]
Y = data[[f'h{k}' for k in range(1, H+1)]]


from sklearn.preprocessing import StandardScaler

n = len(X)
i_tr  = int(n*0.70)
i_val = int(n*0.85)

X_tr,  X_val,  X_te  = X.iloc[:i_tr],  X.iloc[i_tr:i_val],  X.iloc[i_val:]
Y_tr,  Y_val,  Y_te  = Y.iloc[:i_tr],  Y.iloc[i_tr:i_val],  Y.iloc[i_val:]

scaler = StandardScaler().fit(X_tr)
X_tr_s  = pd.DataFrame(scaler.transform(X_tr),  index=X_tr.index,  columns=X_tr.columns)
X_val_s = pd.DataFrame(scaler.transform(X_val), index=X_val.index, columns=X_val.columns)
X_te_s  = pd.DataFrame(scaler.transform(X_te),  index=X_te.index,  columns=X_te.columns)



def make_seq2seq(Xdf, Ydf, seq_len=30):
    Xs, Ys = [], []
    for i in range(seq_len, len(Xdf)):
        Xs.append(Xdf.iloc[i-seq_len:i].values)   # (seq_len, F)
        Ys.append(Ydf.iloc[i-seq_len:i].values)   # (seq_len, H)
    return np.array(Xs, np.float32), np.array(Ys, np.float32)

SEQ_LEN = 60
Xtr_seq,  Ytr_seq  = make_seq2seq(X_tr_s,  Y_tr,  seq_len=SEQ_LEN)
Xval_seq, Yval_seq = make_seq2seq(X_val_s, Y_val, seq_len=SEQ_LEN)
Xte_seq,  Yte_seq  = make_seq2seq(X_te_s,  Y_te,  seq_len=SEQ_LEN)

print(Xtr_seq.shape, Ytr_seq.shape)  # -> (N_tr, seq_len, F), (N_tr, seq_len, H)
# Out:
# (1837, 60, 5) (1837, 60, 10)

# %% [markdown]
# # Model construction and fitting

# %%
import tensorflow as tf
from tensorflow import keras

F = Xtr_seq.shape[-1]
H = Ytr_seq.shape[-1]

# %%
import os
root_logdir = os.path.join(os.curdir, "my_logs")
def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()
run_logdir
# Out:
# './my_logs/run_2025_08_31-15_07_05'

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model= keras.models.Sequential([
    keras.Input(shape=(SEQ_LEN, F)),
    keras.layers.GRU(64,return_sequences=True),
    keras.layers.Dropout(rate=0.3),
    keras.layers.GRU(32,return_sequences=True),
    keras.layers.Dropout(rate=0.1),
    keras.layers.TimeDistributed(keras.layers.Dense(H))  # output: (seq_len, H) 
])

loss = tf.keras.losses.Huber(delta=0.3)
optimizer = keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-7,
    clipnorm=1.0  # Gradient clipping per stabilità
)
model.compile(optimizer=optimizer, loss=loss,metrics=['mse','mae','mape'])
es = keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(factor=0.3, patience=7,min_lr=1e-7) #performance scheduling 
#lr_scheduler = keras.callbacks.LearningRateScheduler(exponential_decay_fn)


tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

history = model.fit(
    Xtr_seq, Ytr_seq,
    validation_data=(Xval_seq, Yval_seq),
    epochs=200, batch_size=32, callbacks=[es,tensorboard_cb,lr_scheduler]
)
# Out:
# Epoch 1/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.6984 - mae: 2.4743 - mape: 65.8605 - mse: 8.2862 - val_loss: 0.2124 - val_mae: 0.8412 - val_mape: 24.4333 - val_mse: 1.5264 - learning_rate: 0.0010
# Epoch 2/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1946 - mae: 0.7832 - mape: 20.3648 - mse: 1.2833 - val_loss: 0.0898 - val_mae: 0.4198 - val_mape: 12.5278 - val_mse: 0.4500 - learning_rate: 0.0010
# Epoch 3/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1305 - mae: 0.5649 - mape: 14.9430 - mse: 0.6732 - val_loss: 0.0709 - val_mae: 0.3467 - val_mape: 10.1249 - val_mse: 0.3424 - learning_rate: 0.0010
# Epoch 4/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.1143 - mae: 0.5085 - mape: 13.4012 - mse: 0.5556 - val_loss: 0.0649 - val_mae: 0.3248 - val_mape: 9.3986 - val_mse: 0.3044 - learning_rate: 0.0010
# Epoch 5/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1066 - mae: 0.4816 - mape: 12.6754 - mse: 0.4992 - val_loss: 0.0609 - val_mae: 0.3096 - val_mape: 8.8531 - val_mse: 0.2801 - learning_rate: 0.0010
# Epoch 6/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1004 - mae: 0.4599 - mape: 12.0675 - mse: 0.4574 - val_loss: 0.0581 - val_mae: 0.2989 - val_mape: 8.4785 - val_mse: 0.2618 - learning_rate: 0.0010
# Epoch 7/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0962 - mae: 0.4448 - mape: 11.6481 - mse: 0.4279 - val_loss: 0.0561 - val_mae: 0.2914 - val_mape: 8.2111 - val_mse: 0.2482 - learning_rate: 0.0010
# Epoch 8/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0921 - mae: 0.4303 - mape: 11.2440 - mse: 0.4025 - val_loss: 0.0544 - val_mae: 0.2843 - val_mape: 7.9868 - val_mse: 0.2380 - learning_rate: 0.0010
# Epoch 9/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0889 - mae: 0.4190 - mape: 10.9350 - mse: 0.3829 - val_loss: 0.0530 - val_mae: 0.2790 - val_mape: 7.8168 - val_mse: 0.2295 - learning_rate: 0.0010
# Epoch 10/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0857 - mae: 0.4076 - mape: 10.6178 - mse: 0.3663 - val_loss: 0.0514 - val_mae: 0.2715 - val_mape: 7.6075 - val_mse: 0.2219 - learning_rate: 0.0010
# Epoch 11/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0830 - mae: 0.3980 - mape: 10.3507 - mse: 0.3525 - val_loss: 0.0508 - val_mae: 0.2708 - val_mape: 7.5641 - val_mse: 0.2189 - learning_rate: 0.0010
# Epoch 12/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0804 - mae: 0.3883 - mape: 10.0764 - mse: 0.3404 - val_loss: 0.0497 - val_mae: 0.2661 - val_mape: 7.4125 - val_mse: 0.2146 - learning_rate: 0.0010
# Epoch 13/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0785 - mae: 0.3815 - mape: 9.8862 - mse: 0.3330 - val_loss: 0.0486 - val_mae: 0.2602 - val_mape: 7.2247 - val_mse: 0.2121 - learning_rate: 0.0010
# Epoch 14/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0766 - mae: 0.3741 - mape: 9.6823 - mse: 0.3247 - val_loss: 0.0483 - val_mae: 0.2595 - val_mape: 7.1937 - val_mse: 0.2108 - learning_rate: 0.0010
# Epoch 15/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0754 - mae: 0.3697 - mape: 9.5457 - mse: 0.3211 - val_loss: 0.0475 - val_mae: 0.2537 - val_mape: 7.0486 - val_mse: 0.2084 - learning_rate: 0.0010
# Epoch 16/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0740 - mae: 0.3646 - mape: 9.4058 - mse: 0.3148 - val_loss: 0.0470 - val_mae: 0.2511 - val_mape: 6.9551 - val_mse: 0.2064 - learning_rate: 0.0010
# Epoch 17/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0729 - mae: 0.3603 - mape: 9.2773 - mse: 0.3110 - val_loss: 0.0467 - val_mae: 0.2499 - val_mape: 6.9141 - val_mse: 0.2054 - learning_rate: 0.0010
# Epoch 18/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0721 - mae: 0.3571 - mape: 9.1840 - mse: 0.3083 - val_loss: 0.0468 - val_mae: 0.2526 - val_mape: 6.9733 - val_mse: 0.2065 - learning_rate: 0.0010
# Epoch 19/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0713 - mae: 0.3541 - mape: 9.0979 - mse: 0.3050 - val_loss: 0.0463 - val_mae: 0.2473 - val_mape: 6.8152 - val_mse: 0.2050 - learning_rate: 0.0010
# Epoch 20/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0706 - mae: 0.3514 - mape: 9.0237 - mse: 0.3026 - val_loss: 0.0464 - val_mae: 0.2511 - val_mape: 6.9098 - val_mse: 0.2051 - learning_rate: 0.0010
# Epoch 21/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0693 - mae: 0.3465 - mape: 8.8794 - mse: 0.2976 - val_loss: 0.0460 - val_mae: 0.2474 - val_mape: 6.8075 - val_mse: 0.2043 - learning_rate: 0.0010
# Epoch 22/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0689 - mae: 0.3448 - mape: 8.8331 - mse: 0.2961 - val_loss: 0.0464 - val_mae: 0.2526 - val_mape: 6.9634 - val_mse: 0.2053 - learning_rate: 0.0010
# Epoch 23/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0682 - mae: 0.3420 - mape: 8.7552 - mse: 0.2935 - val_loss: 0.0457 - val_mae: 0.2442 - val_mape: 6.7218 - val_mse: 0.2035 - learning_rate: 0.0010
# Epoch 24/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0678 - mae: 0.3402 - mape: 8.7030 - mse: 0.2919 - val_loss: 0.0457 - val_mae: 0.2448 - val_mape: 6.7206 - val_mse: 0.2031 - learning_rate: 0.0010
# Epoch 25/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0672 - mae: 0.3380 - mape: 8.6427 - mse: 0.2892 - val_loss: 0.0457 - val_mae: 0.2438 - val_mape: 6.7070 - val_mse: 0.2038 - learning_rate: 0.0010
# Epoch 26/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0668 - mae: 0.3363 - mape: 8.5886 - mse: 0.2881 - val_loss: 0.0456 - val_mae: 0.2431 - val_mape: 6.6848 - val_mse: 0.2037 - learning_rate: 0.0010
# Epoch 27/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0661 - mae: 0.3337 - mape: 8.5138 - mse: 0.2854 - val_loss: 0.0454 - val_mae: 0.2420 - val_mape: 6.6444 - val_mse: 0.2028 - learning_rate: 0.0010
# Epoch 28/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0657 - mae: 0.3323 - mape: 8.4773 - mse: 0.2842 - val_loss: 0.0453 - val_mae: 0.2408 - val_mape: 6.6197 - val_mse: 0.2026 - learning_rate: 0.0010
# Epoch 29/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0652 - mae: 0.3301 - mape: 8.4141 - mse: 0.2819 - val_loss: 0.0451 - val_mae: 0.2415 - val_mape: 6.6212 - val_mse: 0.2016 - learning_rate: 0.0010
# Epoch 30/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0650 - mae: 0.3295 - mape: 8.3938 - mse: 0.2809 - val_loss: 0.0452 - val_mae: 0.2407 - val_mape: 6.6094 - val_mse: 0.2026 - learning_rate: 0.0010
# Epoch 31/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0647 - mae: 0.3281 - mape: 8.3612 - mse: 0.2797 - val_loss: 0.0452 - val_mae: 0.2413 - val_mape: 6.6265 - val_mse: 0.2026 - learning_rate: 0.0010
# Epoch 32/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0642 - mae: 0.3262 - mape: 8.3054 - mse: 0.2773 - val_loss: 0.0452 - val_mae: 0.2415 - val_mape: 6.6122 - val_mse: 0.2020 - learning_rate: 0.0010
# Epoch 33/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0637 - mae: 0.3247 - mape: 8.2589 - mse: 0.2756 - val_loss: 0.0450 - val_mae: 0.2418 - val_mape: 6.6214 - val_mse: 0.2012 - learning_rate: 0.0010
# Epoch 34/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0633 - mae: 0.3228 - mape: 8.2096 - mse: 0.2742 - val_loss: 0.0450 - val_mae: 0.2411 - val_mape: 6.5865 - val_mse: 0.2018 - learning_rate: 0.0010
# Epoch 35/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0629 - mae: 0.3214 - mape: 8.1736 - mse: 0.2721 - val_loss: 0.0449 - val_mae: 0.2420 - val_mape: 6.5988 - val_mse: 0.2012 - learning_rate: 0.0010
# Epoch 36/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0626 - mae: 0.3203 - mape: 8.1380 - mse: 0.2714 - val_loss: 0.0450 - val_mae: 0.2394 - val_mape: 6.5736 - val_mse: 0.2010 - learning_rate: 0.0010
# Epoch 37/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0620 - mae: 0.3179 - mape: 8.0798 - mse: 0.2685 - val_loss: 0.0449 - val_mae: 0.2402 - val_mape: 6.5736 - val_mse: 0.2007 - learning_rate: 0.0010
# Epoch 38/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0617 - mae: 0.3168 - mape: 8.0416 - mse: 0.2673 - val_loss: 0.0449 - val_mae: 0.2401 - val_mape: 6.5966 - val_mse: 0.2008 - learning_rate: 0.0010
# Epoch 39/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0610 - mae: 0.3141 - mape: 7.9722 - mse: 0.2641 - val_loss: 0.0448 - val_mae: 0.2422 - val_mape: 6.6070 - val_mse: 0.2002 - learning_rate: 0.0010
# Epoch 40/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0605 - mae: 0.3124 - mape: 7.9284 - mse: 0.2622 - val_loss: 0.0449 - val_mae: 0.2409 - val_mape: 6.5694 - val_mse: 0.2006 - learning_rate: 0.0010
# Epoch 41/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0602 - mae: 0.3113 - mape: 7.8952 - mse: 0.2598 - val_loss: 0.0450 - val_mae: 0.2406 - val_mape: 6.5846 - val_mse: 0.1996 - learning_rate: 0.0010
# Epoch 42/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0596 - mae: 0.3091 - mape: 7.8362 - mse: 0.2573 - val_loss: 0.0451 - val_mae: 0.2411 - val_mape: 6.6102 - val_mse: 0.1999 - learning_rate: 0.0010
# Epoch 43/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0589 - mae: 0.3064 - mape: 7.7672 - mse: 0.2536 - val_loss: 0.0453 - val_mae: 0.2436 - val_mape: 6.6512 - val_mse: 0.2001 - learning_rate: 0.0010
# Epoch 44/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0583 - mae: 0.3041 - mape: 7.7068 - mse: 0.2500 - val_loss: 0.0455 - val_mae: 0.2436 - val_mape: 6.6770 - val_mse: 0.1994 - learning_rate: 0.0010
# Epoch 45/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0577 - mae: 0.3017 - mape: 7.6387 - mse: 0.2474 - val_loss: 0.0459 - val_mae: 0.2447 - val_mape: 6.7566 - val_mse: 0.2012 - learning_rate: 3.0000e-04
# Epoch 46/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0576 - mae: 0.3014 - mape: 7.6293 - mse: 0.2466 - val_loss: 0.0462 - val_mae: 0.2458 - val_mape: 6.7860 - val_mse: 0.2015 - learning_rate: 3.0000e-04
# Epoch 47/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0574 - mae: 0.3006 - mape: 7.6101 - mse: 0.2456 - val_loss: 0.0461 - val_mae: 0.2457 - val_mape: 6.7753 - val_mse: 0.2016 - learning_rate: 3.0000e-04
# Epoch 48/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0570 - mae: 0.2994 - mape: 7.5837 - mse: 0.2434 - val_loss: 0.0466 - val_mae: 0.2478 - val_mape: 6.8505 - val_mse: 0.2026 - learning_rate: 3.0000e-04
# Epoch 49/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0569 - mae: 0.2992 - mape: 7.5756 - mse: 0.2430 - val_loss: 0.0464 - val_mae: 0.2473 - val_mape: 6.8119 - val_mse: 0.2021 - learning_rate: 3.0000e-04
# Epoch 50/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0564 - mae: 0.2974 - mape: 7.5260 - mse: 0.2407 - val_loss: 0.0465 - val_mae: 0.2476 - val_mape: 6.8324 - val_mse: 0.2026 - learning_rate: 3.0000e-04
# Epoch 51/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0563 - mae: 0.2970 - mape: 7.5237 - mse: 0.2397 - val_loss: 0.0469 - val_mae: 0.2498 - val_mape: 6.8706 - val_mse: 0.2045 - learning_rate: 3.0000e-04
# Epoch 52/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0561 - mae: 0.2961 - mape: 7.4942 - mse: 0.2387 - val_loss: 0.0467 - val_mae: 0.2488 - val_mape: 6.8409 - val_mse: 0.2037 - learning_rate: 9.0000e-05
# Epoch 53/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0559 - mae: 0.2953 - mape: 7.4733 - mse: 0.2375 - val_loss: 0.0469 - val_mae: 0.2492 - val_mape: 6.8601 - val_mse: 0.2039 - learning_rate: 9.0000e-05
# Epoch 54/200
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0559 - mae: 0.2955 - mape: 7.4812 - mse: 0.2375 - val_loss: 0.0470 - val_mae: 0.2498 - val_mape: 6.8555 - val_mse: 0.2047 - learning_rate: 9.0000e-05

# %%
test = model.evaluate(Xte_seq, Yte_seq, verbose=0)
print("Test:", test)
# Out:
# Test: [0.04302234947681427, 0.17807817459106445, 0.24154049158096313, 6.50422477722168]

# %%
Y_pred = model.predict(Xte_seq, verbose=0)   

h_names = [f"h{k}" for k in range(1, H+1)]
today_true = Yte_seq[-1, -1, :]              

kH = H-1

plt.figure(figsize=(10,4))
plt.plot(Yte_seq[-300:, -1, kH], label=f"true h{H}")
plt.plot(Y_pred[-300:, -1, kH], label=f"pred h{H}", alpha=0.8)
plt.legend(); plt.title(f" True vs Predictions ")
plt.grid(True); plt.show()
